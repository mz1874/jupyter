# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5])
y = np.array([12,34,56,23,56])

plt.plot(x,y)
# 水平线
plt.hlines(30,1,4)
# 垂直线
plt.vlines(2,10, 50)
plt.vlines(3,-20, 50)

# 画多个线
plt.vlines([1,2,2.5], 20, 30, linestyles='-')
plt.show()
